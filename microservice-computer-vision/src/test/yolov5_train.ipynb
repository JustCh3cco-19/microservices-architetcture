# %% [markdown]
# # **Cone detection train notebook.**

# %% [markdown]
# ### **Step 1**: Mount the Google Drive storage

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### **Step 2**: Clone YOLOv5 from GitHub repository

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# %pip install -qr requirements.txt

import torch

print('Setup complete.\n\nTorch version:\t{}\n\nDevice:\t'.format(torch.__version__), end='')

if torch.cuda.is_available():
  device = torch.cuda.get_device_properties(0)
  print('{}\n  -Major compute capability version number: {}\n  -Minor compute capability version number: {}\n  -Memory: {}MB\n  -Processors: {}'.format(device.name, device.major, device.minor, int(device.total_memory/1048576), device.multi_processor_count))
else:
  print('CPU')

# %% [markdown]
# ### **Step 3**: Launch the training script (The hyperparameters here are indicative only)

# %%
# !python train.py --img 640 --batch 32 --epochs 100 --data /content/drive/MyDrive/Colab/Dataset/640x/yolo_train.yml --weights /content/drive/MyDrive/Colab/640x32.pt --nosave --cache
# Out:
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v5.0-81-gabfcf9e torch 1.8.1+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=32, bbox_interval=-1, bucket='', cache_images=True, cfg='', data='/content/drive/MyDrive/Colab/Dataset/640x/yolo_train.yml', device='', entity=None, epochs=100, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='exp', noautoanchor=False, nosave=True, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/exp2', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=32, upload_dataset=False, weights='/content/drive/MyDrive/Colab/640x32.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %% [markdown]
# ### **Step4**: Clone the NN and the logs into Google Drive storage (Note: if the last epoch are not the poc with best results, the optimized weights are saved in _best.pt_

# %%
# !mv runs/train/exp/weights/last.pt /content/drive/MyDrive/Colab/640x32.pt
# !mv runs/train/exp /content/drive/MyDrive/Colab/640res32

# %%
# !python detect.py --source /content/drive/MyDrive/Colab/test640.png --weights /content/drive/MyDrive/Colab/640x32.pt --conf 0.1
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.1, device='', exist_ok=False, hide_conf=False, hide_labels=False, img_size=640, iou_thres=0.45, line_thickness=3, name='exp', nosave=False, project='runs/detect', save_conf=False, save_crop=False, save_txt=False, source='/content/drive/MyDrive/Colab/test640.png', update=False, view_img=False, weights=['/content/drive/MyDrive/Colab/640x32.pt'])
# YOLOv5 🚀 v5.0-81-gabfcf9e torch 1.8.1+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7053910 parameters, 0 gradients, 16.3 GFLOPS
# image 1/1 /content/drive/MyDrive/Colab/test640.png: 640x640 42 cones, Done. (0.012s)
# Results saved to runs/detect/exp
# Done. (0.704s)
